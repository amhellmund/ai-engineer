# %% [markdown]
# # Day 1 — What is AI Engineering? · Coding Tasks
#
# Paired notebook for the [Day 1 tutorial](https://amhellmund.github.io/ai-engineering-in-100-days/sections/01-foundations/01-what-is-ai-engineering.html).
#
# No GPU needed — these tasks are pure Python and explore the **token economics** of LLM features. Fill in the `TODO`s.

# %% [markdown]
# ## Task 1 — An LLM cost estimator
#
# Write `monthly_cost(t_in, t_out, volume, p_in, p_out)` returning the estimated monthly cost in dollars.
# `p_in` / `p_out` are prices per **1 million** tokens; `volume` is requests per month.
#
# Then estimate a feature with 800 input tokens, 250 output tokens, 120,000 requests/month at $3 / $15 per 1M tokens (expected: $738.00 / month).

# %%
def monthly_cost(t_in, t_out, volume, p_in, p_out):
    # TODO: cost per call = (t_in/1e6)*p_in + (t_out/1e6)*p_out, then times volume
    raise NotImplementedError


cost = monthly_cost(800, 250, 120_000, 3.00, 15.00)
print(f"${cost:,.2f} / month")

# %% [markdown]
# ## Task 2 — Pick the cheaper model
#
# Given a dict of candidate models (each with `p_in` and `p_out` per 1M tokens) and a fixed workload,
# write `cheapest(models, t_in, t_out, volume)` returning the **name** of the lowest-cost model.
# Verify it returns `'cheap'` on the dictionary below.

# %%
def cheapest(models, t_in, t_out, volume):
    # TODO: compute each model's monthly_cost and return the name of the minimum
    raise NotImplementedError


models = {
    "capable": {"p_in": 3.00, "p_out": 15.00},
    "cheap":   {"p_in": 0.25, "p_out": 1.25},
    "mid":     {"p_in": 1.00, "p_out": 5.00},
}
print(cheapest(models, 1500, 400, 50_000))
