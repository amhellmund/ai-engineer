# %% [markdown]
# # Day 2 — Setting Up Your AI Engineering Environment · Coding Tasks
#
# Paired notebook for the [Day 2 tutorial](https://amhellmund.github.io/ai-engineering-in-100-days/sections/01-foundations/02-environment-setup.html).
#
# No GPU needed — these are tiny "does my environment actually work?" self-tests. Fill in the `TODO`s.

# %% [markdown]
# ## Task 1 — Environment self-check
#
# Write `env_report()` that prints the running Python version (use `sys.version_info`) and the platform,
# then **asserts** Python is at least **3.10** (raise a clear error otherwise). Call it to confirm your
# interpreter is the one you expect.

# %%
import sys
import platform


def env_report():
    # TODO: print sys.version_info (major.minor.micro) and platform.system()/machine()
    # TODO: assert sys.version_info >= (3, 10) with a clear message
    raise NotImplementedError


env_report()

# %% [markdown]
# ## Task 2 — Confirm a package is installed and working
#
# A real test imports a third-party package and *uses* it. Write `check_numpy()` that imports `numpy`,
# prints its version (`numpy.__version__`), builds the array `[1, 2, 3]`, and asserts its sum equals `6`.
# If the import fails, print a helpful message telling the reader to run `uv add numpy` (or `pip install numpy`).

# %%
def check_numpy():
    # TODO: try to import numpy; on ImportError, print an install hint and return
    # TODO: print numpy.__version__, build np.array([1, 2, 3]), assert its sum == 6
    raise NotImplementedError


check_numpy()
