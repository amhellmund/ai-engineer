# %% [markdown]
# # Day 3 — NumPy Arrays & Vectorization · Coding Tasks
#
# Paired notebook for the [Day 3 tutorial](https://amhellmund.github.io/ai-engineering-in-100-days/sections/01-foundations/03-numpy-arrays-and-vectorization.html).
#
# Fill in the `TODO`s. Reference solutions are in the tutorial under each task's *Show solution*.
#
# Day 3 runs fine on CPU — no GPU runtime needed.

# %%
import numpy as np

# %% [markdown]
# ## Task 1 — Vectorize a distance computation
#
# Given `points` of shape `(N, 2)` and `origin` of shape `(2,)`, return a 1-D array of the
# Euclidean distance from each point to `origin`. **No Python `for` loop.**
#
# $d_i = \sqrt{(x_i - o_x)^2 + (y_i - o_y)^2}$

# %%
def distances(points, origin):
    # TODO: use broadcasting + a vectorized sqrt; no loops
    raise NotImplementedError


points = np.array([[0.0, 0.0], [3.0, 4.0], [1.0, 1.0]])
origin = np.array([0.0, 0.0])
# Expected: array([0.        , 5.        , 1.41421356])
distances(points, origin)

# %% [markdown]
# ## Task 2 — Min–max normalize each column
#
# Rescale **each column** independently to `[0, 1]` via $x' = (x - \min) / (\max - \min)$.
# Use broadcasting, no loops, and guard against divide-by-zero (a constant column should
# become all zeros).

# %%
def minmax(m):
    # TODO: per-column min/max with axis=0, guard span == 0
    raise NotImplementedError


m = np.array([[1.0, 5.0, 7.0],
              [3.0, 5.0, 9.0],
              [2.0, 5.0, 8.0]])
# Middle column is constant -> should come out all zeros
minmax(m)
